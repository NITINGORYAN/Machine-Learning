# %%
import numpy as np
import pandas as pd

# %%
Data=pd.read_csv('/insurance.csv')

# %%
Data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
Data['sex']=Data['sex'].apply({'male':0,'female':1}.get)

# %%
Data.head()
# Out:
#    age  sex   bmi  children smoker     region  expenses
# 0   19    1  27.9         0    yes  southwest  16884.92
# 1   18    0  33.8         1     no  southeast   1725.55
# 2   28    0  33.0         3     no  southeast   4449.46
# 3   33    0  22.7         0     no  northwest  21984.47
# 4   32    0  28.9         0     no  northwest   3866.86

# %%
Data['smoker']=Data['smoker'].apply({'yes':0,'no':1}.get)

# %%
Data.head()
# Out:
#    age  sex   bmi  children  smoker     region  expenses
# 0   19    1  27.9         0       0  southwest  16884.92
# 1   18    0  33.8         1       1  southeast   1725.55
# 2   28    0  33.0         3       1  southeast   4449.46
# 3   33    0  22.7         0       1  northwest  21984.47
# 4   32    0  28.9         0       1  northwest   3866.86

# %%
Data['region']=Data['region'].apply({'southwest':0,'southeast':1,'northwest':2,'northeast':3}.get)

# %%
Data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    1  27.9         0       0       0  16884.92
# 1   18    0  33.8         1       1       1   1725.55
# 2   28    0  33.0         3       1       1   4449.46
# 3   33    0  22.7         0       1       2  21984.47
# 4   32    0  28.9         0       1       2   3866.86

# %%
x = Data[['age','sex','bmi','children','smoker','region']]
y = Data['expenses']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=regression.predict(x_test)

# %%
regression.score(x,y)
# Out:
# 0.7504123926862922

# %% [markdown]
# Calculating the insurance of new customer

# %%
Data_new={"age":20,"sex":1,"bmi":29,"children":2,"smoker":1,"region":2}

# %%
index=[1]

# %%
my_Data=pd.DataFrame(Data_new,index)

# %%
my_Data
# Out:
#    age  sex  bmi  children  smoker  region
# 1   20    1   29         2       1       2

# %%
new_predicition=regression.predict(my_Data)
print('cost of health insurance is ', new_predicition)
# Out:
# cost of health insurance is  [3648.5584996]
